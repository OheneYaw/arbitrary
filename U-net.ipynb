# %% [markdown]
# ## [Problem 1] Learning / estimation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.comunet.git
# Out:
# Cloning into 'github.comunet'...
# fatal: unable to access 'https://github.comunet.git/': Could not resolve host: github.comunet.git

# %%
cd drive/MyDrive/unet
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/unet'
# /content

# %%
# !python main.py
# Out:
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory

# %%
from model import *
from data import *

data_gen_args = dict(rotation_range=0.2,
                     width_shift_range=0.05,
                     height_shift_range=0.05,
                     shear_range=0.05,
                     zoom_range=0.05,
                     horizontal_flip=True,
                     fill_mode='nearest')

myGene = trainGenerator(20,
                        'data/membrane/train',
                        'image',
                        'label',
                        data_gen_args,
                        save_to_dir = None)

model = unet()
model_checkpoint = ModelCheckpoint('unet_salt.hdf5',
                                   monitor='loss',
                                   verbose=1,
                                   save_best_only=True)

model.fit_generator(myGene,
                    steps_per_epoch=10,
                    epochs=5,
                    callbacks=[model_checkpoint])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-e681e953c6f6> in <cell line: 1>()
# ----> 1 from model import *
#       2 from data import *
#       3
#       4 data_gen_args = dict(rotation_range=0.2,
#       5                      width_shift_range=0.05,
#
# ModuleNotFoundError: No module named 'model'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
gene = testGenerator('data/membrane/test')
unet = unet()
unet.load_weights('unet_salt.hdf5')
pred = model.predict_generator(gene,10,verbose=1)
saveResult("data/membrane/test",pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-2282f4cfcce0> in <cell line: 1>()
# ----> 1 gene = testGenerator('data/membrane/test')
#       2 unet = unet()
#       3 unet.load_weights('unet_salt.hdf5')
#       4 pred = model.predict_generator(gene,10,verbose=1)
#       5 saveResult("data/membrane/test",pred)
#
# NameError: name 'testGenerator' is not defined

# %% [markdown]
# ## [Problem 2] Code reading

# %% [markdown]
# - In this paper, we present a network and training strategy that relies on the strong
# use of data augmentation to use the available annotated samples more
# efficiently.
#
# - This network is based on a fully convolutional network, it also uses many layers and in this network pooling operations are replaced with upsampling operators
